# %% [markdown]
# # Notebook 7 - Crear y consultar una Base de Datos no relacional orientada a Documentos (Mongo)

# %% [markdown]
# ## Ejercicio 1: Primeros pasos desde Mongo CLI

# %% [markdown]
# En un terminal, verificar si el SGBD Mongo ya está iniciado:
#
# <code>ps -aux | grep mongod</code>
#
# Si no está iniciado, iniciarlo con el comando: <code>mongod</code>
#
# Luego, abrir otra pestaña de terminal (CTRL + Shift + T) e iniciar el cliente CLI de mongo: <code>mongo</code>.

# %% [markdown]
# 1) Creamos una nueva base de datos llamado <b>nb7-peliculas</b>
#
# <code>use nb7-peliculas</code>
#
# Deberian ver como respuesta del sistema la respuesta: "switched to db nb7-peliculas"

# %% [markdown]
# Mongo CLI no utiliza SQL para realizar operaciones CRUD (Create/Read/Update/Delete), utiliza su propia API parecida al lenguaje Javascript.
#
# La variable <code>db</code> representa siempre la base de datos que estamos utilizando (en este caso "nb7-peliculas").
#
# 2) Creamos una colección <b>actors</b>
#
# <code>db.actors.insert({firstname:"Will", lastname:"Smith"})</code>
#
# Como pueden verlo, para crear la colección no tuvimos que definir la estructura de la colección, simplemente hemos insertado un documento.
#
# Verificamos que hemos realmente creado la coleccion con:
#
# <code>db.actors.find()</code>
#
# 3) Insertamos varios documentos en la colección en un solo comando:
#
# <code>db.actors.insertMany([{firstname:"Scarlett", lastname:"Johanson"},{firstname:"Matt", lastname:"Damon"},{firstname:"Nathan", lastname:"Smith"}])</code>
#
# 4) Contamos cuántos documentos tenemos en la colección:
#
# <code>db.actors.count()</code>
#
# Como en SQL, la API de Mongo permite construir consultas para filtrar, ordenar o agrupar datos. Sin embargo, la síntaxis es distinta (y amenudo menos simple e intuitiva que SQL).
#
# 5) Filtramos los actores que se llaman 'Smith'
#
# <code>db.actors.find({lastname:"Smith"})</code>
#
# Mongo tambien permite modificar los datos (ojo: Mongo no tiene mecanismo interno para asegurar la coherencia de los datos, es la responsabilidad del programador de la aplicación).
#
# 6) Actualizamos un documento. Por ejemplo, "Nathan Smith" se llama ahora "Nathan Lane"
#
# <code>db.actors.update({firstname:"Nathan", lastname:"Smith"},{$set : {lastname:"Lane"}})</code>
#
# Este último comando va a actualizar el primer documento encontrado que corresponde al filtro definido.
#
# 7) Supongamos ahora que queremos agregar un campo "gender" en todos los documentos:
#
# ¿Qué hace el comando siguiente? ¿Cuál es el limite?
#
# <code>db.actors.update({},{$set : {gender:"M"}})</code>
#
# Para actualizar todos los documentos, y no simplemente el primero, podemos utilizar el comando:
#
# <code>db.actors.update({},{$set : {gender:"M"}},{multi:true})</code>
#
# 8) Actualizar el documento "Scarlett Johanson", para indicar que es una mujer (gender:"F").
#
# 9) Para suprimir un atributo, podemos utilizar el operador $unset. Por ejemplo:
#
# <code>db.actors.update({},{$unset : {gender:1}},{multi:true})</code>
#
# 10) Para suprimir un documento completo, podemos utilizar el comando:
#
# <code>db.actors.remove({lastname:"Smith"})</code>
#
# 11) Agregamos un atributo de tipo arreglo en un documento
#
# <code>db.actors.update({firstname:"Matt"},{$set : {tab:[1,"a"]}})</code>
#
# 12) Añadimos un valor en el arreglo con el operator $push
#
# <code>db.actors.update({firstname:"Matt"},{$push : {tab:["new_value"]}})</code>
#
# ¿Cuál es el problema con el último comando? ¿Cuál es la diferencia con el comando siguiente?
#
# <code>db.actors.update({firstname:"Matt"},{$push : {tab:"new_value"}})</code>
#
# Cómo pueden verlo el SGBD no relacional Mongo es mucho más flexible que MySQL, pero deja mucho más posibilidad de equivocarse.
#
#
# No duden en consultar la documentación de Mongo para probar otros comandos CRUD: https://docs.mongodb.com/manual/crud/

# %% [markdown]
# ## Ejercicio 2: Primeras consultas avanzadas con una colección de peliculas
#
# En este segundo ejercicio, trabajaremos con una base de datos existente llamada "movie details", la cual tiene 2295 documentos JSON resumiendo información sobre peliculas.
#
# - Descargar el dataset https://raw.githubusercontent.com/steveren/docs-assets/charts-tutorial/movieDetails.json. ¿Qué contiene este archivo? Un documento JSON? Un arreglo de documentos JSON? Una lista de documentos JSON?
#
# - Importamos los datos en Mongo con el comando siguiente:
#
# <code>mongoimport --db nb7-peliculas --collection movieDetails --drop --file <path/to/movieDetails.json></code>
#
# A continuación, queremos realizar algunas consultas típicas para observar la diferencia entre el lenguaje de consulta SQL y el lenguaje de Mongo.
#
# <b>Nota bena</b>: ¿Qué pasa si agregan la función <code>.pretty()</code> al final de un comando? Por ejemplo: <code>db.actors.find().pretty()</code>
#
# 1) Utilizar un comando Mongo para contar cuántos documentos hay en la colección 'movieDetails'. ¿Cuál sería el equivalente en SQL?
#
# 2) Mostrar los títulos (title) y años de producción (year) de todas las peliculas de la colección. ¿A qué clausula SQL correspondría?
#
# 3) Contar las peliculas realizadas entre 1990 y 2000
#
# 4) ¿Cuáles son los titulos de peliculas que ganaron más de 5 awards?
#
# 5) ¿Cuál es el rating promedio en el sitio imdb para todas las peliculas?
#
# 6) ¿Cuáles son las peliculas en las cuales participó el actor Nicolas Cage?
#
# 7) ¿Cuál es el número de pelicula por año?
#
# 8) ¿Cuál es la pelicula con el mejor rating?
#
# 9) ¿Cuáles son los thrillers con un rating de al meno 6?
#
# 10) ¿Cuáles son todos los valores de generos posibles?
#
# 11) ¿Cuáles son las peliculas que contienen la palabra 'Star'?
#
# 12) ¿Cuáles son los títulos que empiezan con la letra 'T'?
#
# 13) ¿Cuáles son las peliculas que no son de tipo Drama o Thriller?

# %% [markdown]
# ## Ejercicio 3: Integrar Mongo con Python
#
# Desde un entorno Python, conectarse a su base de datos movieDetails y realizar consultas similares al ejercicio 2.

# %%
from mongoengine import * 
connect('nb7-peliculas')


class tomato(EmbeddedDocument):
    meter = IntField()
    image = StringField()
    rating = IntField() 
    reviews = IntField() 
    fresh = IntField()
    consensus = StringField()
    userMeter = IntField()
    userRating = DecimalField()
    userReviews = IntField()
class imdb(EmbeddedDocument):
    id = StringField()
    StringField()
    rating = DecimalField()
    votes = IntField()
class awards(EmbeddedDocument):
    wins = IntField()
    nominations = IntField()
    text = StringField()
    oscars = IntField()
class movie_details(Document):
    title = StringField()
    year = IntField()
    rated = StringField()
    runtime = IntField()
    countries = ListField(StringField())
    genres = ListField(StringField())
    director = StringField()
    writers = ListField(StringField())
    actors = ListField(StringField())
    plot = StringField()
    poster = StringField()
    imdb = EmbeddedDocumentField(imdb)
    tomato = EmbeddedDocumentField(tomato)
    metacritic = IntField()
    awards = EmbeddedDocumentField(awards)
    type = StringField()

# %%
#1) Utilizar un comando Mongo para contar cuántos documentos hay en la colección 'movieDetails'. ¿Cuál sería el equivalente en SQL?
n = len(movie_details.objects)
print("Hay " + str(n) + " documentos en la coleccion")
#db.movie_details.find().count()

#2) Mostrar los títulos (title) y años de producción (year) de todas las peliculas de la colección. 
#¿A qué clausula SQL correspondría?
print("\n\nTitulos y años de produccion de todas las peliculas de la coleccion: ")
for i in movie_details.objects:
    #print(i.title + " " + str(i.year))
    pass
#3) Contar las peliculas realizadas entre 1990 y 2000
c = 0
for i in movie_details.objects:
    if (i.year >= 1990 and i.year <= 2000):
        c+=1
print("\n\nHay " + str(c) + " peliculas realizadas entre 1990 y 2000")
#4) ¿Cuáles son los titulos de peliculas que ganaron más de 5 awards?
for i in movie_details.objects:
    if (i.awards):
        if (i.awards.wins > 5):
            #print(i.title)
            pass
#5) ¿Cuál es el rating promedio en el sitio imdb para todas las peliculas?
suma = 0
for i in movie_details.objects:
    if (i.imdb.rating):
        suma += i.imdb.rating
print("\n\nEl promedio de rating promedio es: " + str(suma / n))

#6) ¿Cuáles son las peliculas en las cuales participó el actor Nicolas Cage?

print("\n\nLas peliculas en las cuales participo el actor Nicolas Cage son:")
for i in movie_details.objects:
    for j in i.actors:
        if j == "Nicolas Cage":
            print("--" + i.title)

years = {}
#7) ¿Cuál es el número de pelicula por año?
for i in movie_details.objects:
    if (not i.year in years):
        years[i.year] = 1
    else:
        years[i.year]+=1
print("\n\nEl numero de peliculas por año son: ")
print(years)

#8) ¿Cuál es la pelicula con el mejor rating?
best_imdb = 0
best_imdb_title = ""
best_tomato = 0
best_tomato_title = ""
for i in movie_details.objects:
    if (i.imdb.rating and i.imdb.rating > best_imdb):
        best_imdb_title = i.title
        best_imdb = i.imdb.rating
    if ((i.tomato) and (i.tomato.rating > best_tomato)):
        best_tomato_title = i.title
        best_tomato = i.tomato.rating
print("\n\nLa mejor segun imdb es: " + best_imdb_title)
print("La mejor segun tomato es: " + best_tomato_title)
#9) ¿Cuáles son los thrillers con un rating de al meno 6?
lista = []
for i in movie_details.objects:
    for j in i.genres:
        if (j == "Thriller"):
            if ((i.imdb.rating and i.imdb.rating >= 6) or (i.tomato and i.tomato.rating >= 6)):
                lista.append(i.title)
            break
print("\n\nLas peliculas que son thrillers con un rating de al menos 6 son: ")
print(lista)

generos = {}
#10) ¿Cuáles son todos los valores de generos posibles?
for i in movie_details.objects:
    for j in i.genres:
        if (not j in generos):
            generos[j] = True
print("\n\nTodos los valores de generos posibles son: ")
print(dict.keys(generos))
 
#11) ¿Cuáles son las peliculas que contienen la palabra 'Star'?
titulos_star = []
for i in movie_details.objects:
    if ("Star" in i.title or "star" in i.title):
        titulos_star.append(i.title)
print("\n\nLas peliculas que contienen la palabra star en su titulo son: ")
print(titulos_star)
#12) ¿Cuáles son los títulos que empiezan con la letra 'T'?

titulos_t = []
for i in movie_details.objects:
    if (i.title[0] == "T"):
        titulos_t.append(i.title)
print("\n\nLos titulos que empiezan con la letra T son: ")
print(titulos_t)
#13) ¿Cuáles son las peliculas que no son de tipo Drama o Thriller?

titulos_no_drama_thriller = []
for i in movie_details.objects:
    for j in i.genres:
        if (j == "Thriller") or (j == "Drama"):
            continue
        titulos_no_drama_thriller.append(i.title)
print("\n\nLas peliculas que no son drama o thriller son: ")
print(titulos_no_drama_thriller)
# Out:
# Hay 2295 documentos en la coleccion
#
#
# Titulos y años de produccion de todas las peliculas de la coleccion:
#
#
# Hay 372 peliculas realizadas entre 1990 y 2000
#
#
# El promedio de rating promedio es: 4.848322440087145969498910675
#
#
# Las peliculas en las cuales participo el actor Nicolas Cage son:
# --Red Rock West
# --Wild at Heart
#
#
# El numero de peliculas por año son:
# {1968: 12, 1999: 50, 1961: 11, 2013: 127, 1977: 16, 2012: 103, 2014: 100, 1980: 23, 1983: 8, 1991: 24, 2002: 60, 2005: 73, 2009: 89, 1982: 15, 1996: 32, 1998: 35, 2007: 97, 1964: 13, 2003: 61, 1993: 34, 2015: 73, 1962: 12, 2010: 105, 1963: 9, 2000: 55, 1959: 7, 2006: 80, 1987: 22, 1994: 35, 2008: 75, 1938: 7, 2011: 102, 1988: 31, 1984: 19, 1975: 20, 1971: 20, 1952: 2, 1954: 6, 1951: 6, 1928: 2, 1989: 26, 2004: 65, 1978: 8, 2001: 53, 1981: 25, 1956: 2, 1979: 16, 1992: 26, 1997: 29, 1969: 8, 1986: 36, 1921: 1, 1965: 10, 1930: 5, 1970: 11, 1940: 2, 1941: 4, 1942: 4, 1958: 6, 1974: 10, 1950: 3, 1990: 24, 1972: 12, 1985: 23, 1995: 28, 1957: 6, 1976: 20, 1947: 1, 1914: 3, 1946: 3, 1955: 4, 1967: 5, 1966: 15, 2016: 8, 1902: 5, 1898: 9, 1948: 3, 1973: 15, 1953: 3, 1934: 3, 1912: 2, 1915: 6, 1960: 4, 1919: 2, 1929: 1, 1911: 1, 1931: 2, 1924: 1, 1896: 2, 1899: 4, 1908: 1, 1916: 1, 1906: 2, 1900: 1, 1904: 1, 1901: 6, 1945: 2, 1943: 4, 1939: 3, 1925: 5, 1910: 2, 1949: 2, 1936: 2, 1905: 2, 1933: 4, 1937: 3, 1918: 1, 1920: 1, 1917: 1, 1897: 2, 1926: 1, 1932: 3, 1909: 2, 2018: 1, 1903: 2, 1935: 1, 1944: 2, 1927: 1}
#
#
# La mejor segun imdb es: DP Fantasies 2
# La mejor segun tomato es: Once Upon a Time in the West
#
#
# Las peliculas que son thrillers con un rating de al menos 6 son:
# ['Red Rock West', 'Slow West', 'From Russia with Love', 'From Paris with Love', 'Space Cowboys', "Before the Devil Knows You're Dead", 'False Trail', 'Total western', 'The Man with the Golden Gun', 'Wild Tales', 'Law Abiding Citizen', 'Law of Desire', 'Beyond the Law', 'Shutter Island', 'The Woman in Black', 'Lost Highway', 'Wild at Heart', 'Angel Heart', 'In Time', 'Once Upon a Time in Mexico', 'A Time to Kill', 'Training Day', 'Die Another Day', 'The World Is Not Enough', '30 Days of Night', 'We Own the Night', 'Ab Tak Chhappan', "L'assassino è costretto ad uccidere ancora", '2000 AD', 'Cul-De-Sac', 'Ek Hasina Thi', 'Ee Adutha Kaalath', 'Ee Thanutha Veluppan Kalathu', 'Thick as Thieves', 'As Above, So Below', 'Varg Veum - I mørket er alle ulver grå', 'Salige er de som tørster', "Give 'em Hell Malone", 'Ko', 'Perder es cuestión de método', 'Gekijô ban Bleach: The DiamondDust Rebellion - Mô hitotsu no hyôrinmaru', 'Charlie the Ox', 'The Talented Mr. Ripley', 'The Da Vinci Code', 'Nom de code: DP', 'Mission: Impossible II', 'Nyama nishto po-hubavo ot loshoto vreme', 'Das Geheimnis im Wald', 'Mais im Bundeshuus: le génie helvétique', 'La Femme Nikita', 'Dr. No', 'D.C. Sniper: 23 Days of Fear', 'No Escape', 'No Country for Old Men', 'Na Maloom Afraad', 'ID:A', 'Positive I.D.', 'Before I Go to Sleep', 'Bob le Flambeur', 'KT', 'Le Doulos', 'T.T. Syndrome', 'Filler ve Çimen', 'I Am Legend', 'Who Am I', 'Ax', 'The Hunt for CM 24', 'El Crimen Perfecto (The Perfect Crime)']
#
#
# Todos los valores de generos posibles son:
# dict_keys(['Western', 'Action', 'Comedy', 'Crime', 'Drama', 'Musical', 'Adventure', 'Fantasy', 'Documentary', 'Animation', 'Family', 'Sci-Fi', 'Romance', 'Thriller', 'Mystery', 'Biography', 'Horror', 'Music', 'History', 'War', 'Short', 'Film-Noir', 'Sport', 'Talk-Show', 'News', 'Adult', 'Reality-TV', 'Game-Show'])
#
#
# Las peliculas que contienen la palabra star en su titulo son:
# ['Star Wars: Episode IV - A New Hope', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode VI - Return of the Jedi', 'Star Wars: Episode I - The Phantom Menace', 'Star Wars: Episode II - Attack of the Clones', 'Star Wars: Episode III - Revenge of the Sith', 'Star Trek', 'Star Trek II: The Wrath of Khan', 'Star Trek Into Darkness', 'Star Trek: First Contact', 'Like Stars on Earth', 'Precure Allstars DX', 'Star Cuts 66: K.C. Valentine', 'JJ Star... How Embarrassing', 'Star Trek VI: The Undiscovered Country', 'RE:AX aka Peace Starts With Me', 'CD Ram: Sex Star Interactive', 'Search for a CW Star', 'Search for a CW Star']
#
#
# Los titulos que empiezan con la letra T son:
# ['Turks in Space', 'The Adventures of Priscilla, Queen of the Desert', 'The Adventures of Robin Hood', 'The Many Adventures of Winnie the Pooh', 'The Adventures of Tintin', 'The Adventures of Baron Munchausen', 'The Adventures of Sharkboy and Lavagirl 3-D', 'The Adventures of Buckaroo Banzai Across the 8th Dimension', 'The Extraordinary Adventures of Adèle Blanc-Sec', 'The Truman Show', 'The Rocky Horror Picture Show', 'The Adventures of Rocky & Bullwinkle', 'The Last Picture Show', 'The Greatest Show on Earth', "There's No Business Like Show Business", 'The Evil Dead', 'Treasure Planet', 'The Karate Kid, Part II', 'The Kid', 'The Karate Kid', 'The Heartbreak Kid', 'The Karate Kid', 'The Kid', 'The Hallelujah Trail', 'The Kid with a Bike', 'Trail of the Pink Panther', 'The Big Trail', 'The Decline of Western Civilization Part II: The Metal Years', 'The Decline of Western Civilization', 'Total western', 'The Cowboy Way', 'The Cowboy and the Lady', 'Top Gun', 'The Naked Gun 2½: The Smell of Fear', 'The Man with the Golden Gun', 'The Naked Gun: From the Files of Police Squad!', 'The Texas Chainsaw Massacre', 'Texas Chainsaw 3D', 'The Texas Chainsaw Massacre 2', 'Texas Chainsaw Massacre: The Next Generation', 'The Poseidon Adventure', 'The Texas Chain Saw Massacre', 'The Oogieloves in the Big Balloon Adventure', 'The Texas Chainsaw Massacre: The Beginning', 'The Wild Bunch', 'The Way of the Gun', 'Trouble Bound', 'The Island', 'The Island of Dr. Moreau', 'The Man from Earth', 'The Day the Earth Stood Still', 'The Day the Earth Stood Still', 'The Woman in Black', 'The Other Woman', 'The Woman in Black 2: Angel of Death', 'The Other Woman', 'The Lost World: Jurassic Park', 'The Lost Boys', 'The City of Lost Children', 'True Romance', "Tillie's Punctured Romance", 'The Woman', 'The Little Mermaid', 'The Normal Heart', 'The Beat That My Heart Skipped', 'The Big Lebowski', 'The Big Sleep', 'The Time Machine', "The Time Traveler's Wife", 'The Girl with the Dragon Tattoo', 'The Girl Next Door', 'The Girl with the Dragon Tattoo', 'The Other Boleyn Girl', 'The Girl Who Played with Fire', 'Terminator 2: Judgment Day', 'The Day After Tomorrow', 'Training Day', 'Thor: The Dark World', 'Team America: World Police', 'The World Is Not Enough', 'The Night of the Hunter', 'The Amazing Spider-Man', 'The Amazing Spider-Man 2', 'Toy Story 2', 'Toy Story', 'Toy Story 3', 'The NeverEnding Story', 'The Straight Story', 'The Secret Life of Walter Mitty', 'The Life Aquatic with Steve Zissou', 'The Tree of Life', "Tora pou fevgo ap' ti zoi", "To gelio vgike ap' ton Paradeiso", 'The Notorious B.G.: A Forum with Bill Gates', 'The Unknown Celebrities: B.D. Benedikt', 'The Return of E.C. Gonatas', 'The Land of Eb', 'The Buffalo Chips: Gimme an Eb Minor', 'The Committee Ep 1: Bad Dog', 'The 1986 Annual D.W. Griffith Awards', "The Making of 'Captain Eo'", 'The Best of BJ Thomas Live', 'The Ran(dy)som for Eva', 'Torrente, el brazo tonto de la ley', 'The Earrings of Madame de...', 'The EE British Academy Film Awards', 'The Jazz Channel Presents B.B. King', 'Totally F***ed Up', 'Thick as Thieves', 'The Story of Father Ev', 'Talada ev', 'The Hi-Lo Country', 'Todo lo que tú quieras', "Tout le monde n'a pas eu la chance d'avoir des parents communistes", "The Artist's Studio: E.W. NAY", 'The Passing of J.B. Randall and Company', 'The Ballad of Little Jo', "The Duke: Based on the Memoir 'I'm the Duke' by J.P. Duke", 'The Death of J.P. Cuenca', 'The Story of Qiu Ju', 'The Hated K.P.', 'Taste of KC Williams', 'The KC Challenge', 'Treacle Jr.', 'To Tulsa and Back: On Tour with J.J. Cale', 'The JJ Project', 'Taboo: The Single and the LP', 'Taboo: The Single and the LP', 'Todo es mentira', 'Tod den Hippies!! Es lebe der Punk!', 'The Secret Government: Origin, Identity and Purpose of the Real MJ-12', 'The LS SuperTards', 'Tie jia wu di Ma Li Ya', 'Takot ako, eh!', 'Tous les matins du monde', 'The JD Set 2011: Bowie', 'The JD Set: 2010', 'The Battle of Chantilly (Ox Hill)', 'T ...
# Las peliculas que no son drama o thriller son:
# ['Once Upon a Time in the West', 'Wild Wild West', 'Wild Wild West', 'Wild Wild West', 'West Side Story', 'West Side Story', 'Journey to the West', 'Journey to the West', 'Journey to the West', 'Star Wars: Episode IV - A New Hope', 'Star Wars: Episode IV - A New Hope', 'Star Wars: Episode IV - A New Hope', 'West of Memphis', 'A Million Ways to Die in the West', 'A Million Ways to Die in the West', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode VI - Return of the Jedi', 'Star Wars: Episode VI - Return of the Jedi', 'Star Wars: Episode VI - Return of the Jedi', 'Star Wars: Episode I - The Phantom Menace', 'Star Wars: Episode I - The Phantom Menace', 'Star Wars: Episode I - The Phantom Menace', 'An American Tail: Fievel Goes West', 'An American Tail: Fievel Goes West', 'An American Tail: Fievel Goes West', 'Star Wars: Episode II - Attack of the Clones', 'Star Wars: Episode II - Attack of the Clones', 'Star Wars: Episode II - Attack of the Clones', 'Star Wars: Episode III - Revenge of the Sith', 'Star Wars: Episode III - Revenge of the Sith', 'Star Wars: Episode III - Revenge of the Sith', 'Star Trek', 'Star Trek', 'Star Trek', 'Star Trek II: The Wrath of Khan', 'Star Trek II: The Wrath of Khan', 'Star Trek Into Darkness', 'Star Trek Into Darkness', 'Star Trek Into Darkness', 'Star Trek: First Contact', 'Star Trek: First Contact', 'Star Trek: First Contact', 'Shakespeare in Love', 'Shakespeare in Love', 'P.S. I Love You', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'Love Actually', 'Love Actually', 'I Love You, Man', 'I Love You, Man', 'Red Rock West', 'Slow West', 'Slow West', 'How the West Was Won', 'Love & Other Drugs', 'Love & Other Drugs', 'From Russia with Love', 'From Russia with Love', 'From Paris with Love', 'Punch-Drunk Love', 'Punch-Drunk Love', '2001: A Space Odyssey', '2001: A Space Odyssey', 'I Love You Phillip Morris', 'I Love You Phillip Morris', 'I Love You Phillip Morris', 'Office Space', 'Zathura: A Space Adventure', 'Zathura: A Space Adventure', 'Zathura: A Space Adventure', 'Space Cowboys', 'Space Cowboys', 'Plan 9 from Outer Space', 'Plan 9 from Outer Space', 'Lost in Space', 'Lost in Space', 'Lost in Space', 'Turks in Space', 'Turks in Space', 'Turks in Space', '2001: A Space Travesty', '2001: A Space Travesty', 'Adventures in Babysitting', 'Adventures in Babysitting', 'Adventures in Babysitting', 'The Adventures of Priscilla, Queen of the Desert', 'The Adventures of Priscilla, Queen of the Desert', 'Muppets from Space', 'Muppets from Space', 'Muppets from Space', 'Space Chimps', 'Space Chimps', 'Space Chimps', 'The Adventures of Robin Hood', 'The Adventures of Robin Hood', 'The Adventures of Robin Hood', 'The Many Adventures of Winnie the Pooh', 'The Many Adventures of Winnie the Pooh', 'The Many Adventures of Winnie the Pooh', 'The Adventures of Tintin', 'The Adventures of Tintin', 'The Adventures of Tintin', 'The Adventures of Baron Munchausen', 'The Adventures of Baron Munchausen', 'The Adventures of Baron Munchausen', 'The Adventures of Sharkboy and Lavagirl 3-D', 'The Adventures of Sharkboy and Lavagirl 3-D', 'The Adventures of Sharkboy and Lavagirl 3-D', 'The Adventures of Buckaroo Banzai Across the 8th Dimension', 'The Adventures of Buckaroo Banzai Across the 8th Dimension', 'The Adventures of Buckaroo Banzai Across the 8th Dimension', 'The Extraordinary Adventures of Adèle Blanc-Sec', 'The Extraordinary Adventures of Adèle Blanc-Sec', 'The Extraordinary Adventures of Adèle Blanc-Sec', 'The Rocky Horror Picture Show', 'The Rocky Horror Picture Show', 'The Adventures of Rocky & Bullwinkle', 'The Adventures of Rocky & Bullwinkle', 'The Adventures of Rocky & Bullwinkle', 'Quiz Show', 'Best in Show', 'Show Me Love', 'Show Me Love', 'The Greatest Show on Earth', 'The Greatest Show on Earth', "There's No Business Like Show Business", "There's No Business Lik ...

# %% [markdown]
# ## Ejercicio 4: Conceptos avanzados de Base de Datos: MySQL y Mongo
#
# - <b>Indíce: optimización de consultas</b>
#
# Referencias:
# - Indíces en Mongo: https://docs.mongodb.com/manual/indexes/
# - Indíces en MySQL: https://dev.mysql.com/doc/refman/8.0/en/optimization-indexes.html
# - Introducción a indíces en MySQL: https://www.adictosaltrabajo.com/2015/09/11/introduccion-a-indices-en-mysql/
#
# 1) ¿Qué es un Indíce y de qué sirve?
#
# 2) ¿Cuándo los SGBDs utilizan los Indíces?
#
# 3) ¿Cuáles son los tipos de Indíces en MySQL y Mongo?
#
# 4) Si los indíces son utiles, ¿por qué no crear indíces por cada columna/atributo? ¿Cuáles son los límimtes?
#
# 5) Conectarse a la base de datos 'sakila' de MySQL y ejecutar la consulta siguiente para poder conservar información sobre el rendimiento de consultas:
#
# <code>set profiling=1;</code>
#
# Ejecutar 10 veces la consulta siguiente:
# <code>select * from rental where return_date>="2005-08-25 17:48:44";</code>
#
# Luego, ejecutar el comando:
# <code>show profiles;</code>
#
# ¿Cuál es la duración promedia del SGBD para responder a esta consulta?
#
# 6) Crear un index sobre la columna 'return_date', y medir nuevamente 10 veces el rendimiento de la misma consulta. ¿Cuál es el nuevo valor promedio?
#
# 7) ¿Cómo crear índices en Mongo?
#
# - <b>Transacciones</b>
#
# Referencias:
# - Introducción a Transacciones en MySQL: http://raknarrok.blogspot.com/2011/03/introduccion-transacciones.html
# - Transacción en MySQL: https://dev.mysql.com/doc/refman/8.0/en/commit.html
# - Transacción en Mongo: https://docs.mongodb.com/manual/core/transactions/
#
# 1) ¿Qué es una transacción?
#
# 2) ¿En términos de transacción, cuáles son las características que deberian garantizar un buen SGBD?
#
# 3) En MySQL, crear una tabla <b>bank_user(name VARCHAR(10), account INT)</b> que permite conocer el monto disponible en la cuenta bancaria de algunos usuarios.
#
# 4) Realizar una operación que permita transferir 100.000 pesos del usuario A al usuario B. ¿Cómo garantizar que la operación no va a generar algún incoherencia en los datos? Escribir el código SQL correspondiente.
#
# 5) Supongamos que queremos hacerlo mismo en Mongo. ¿Mongo soporta transacciones ACID? ¿Desde cuándo? ¿Cómo se puede hacer transacciones? ¿Con qué limitaciones?
#
#
# - <b>Sharding y Replicación</b>
#
# 1) ¿Cuál es el principio del Sharding?
#
# 2) ¿Cuál es el principio de la Replicación?
#
# 3) ¿MySQL implementa mecanismos de Sharding/Replicación? y Mongo?
